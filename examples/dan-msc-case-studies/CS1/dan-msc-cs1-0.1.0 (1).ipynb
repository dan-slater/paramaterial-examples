# %% [markdown]
# # CS1 Dataset Report

# %% [markdown]
# Import libraries, and print package versions.

# %%
import paramaterial as pam
from paramaterial import DataSet, DataItem, ModelSet
from paramaterial.models import ramberg
import os
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt

print(pam.__version__)
print(pd.__version__)
print(sns.__version__)
print(mpl.__version__)
# Out:
# 0.1.0
# 1.5.3
# 0.12.2
# 3.7.0

# %% [markdown]
# ### Gather data and info

# %% [markdown]
# Extract info from the filenames and make the info table.

# %%
info_lists = [[filename] + filename.split('_')[:4] for filename in os.listdir('data/01 raw data')]
info_table = pd.DataFrame(info_lists,
                          columns=['old_filename', 'test_type', 'temperature', 'lot', 'number']
                          ).sort_values(by='test_type', ascending=False)

# %% [markdown]
# Add a unique test ID column.

# %%
info_table['test_id'] = [f'test_ID_{i + 1:03d}' for i in range(len(info_table))]
info_table = info_table.set_index('test_id').reset_index()  # move the test_id column to the far left

# %% [markdown]
# Drop the PST tests. We are only going to be processing and analysing the uniaxial tests.

# %%
info_table['test_type'] = info_table['test_type'].replace('T', 'UT')
info_table['test_type'] = info_table['test_type'].replace('P', 'PST')
info_table = info_table[info_table['test_type'] != 'PST']
info_table = info_table[~info_table['lot'].isin(list('FGHI'))]

# %% [markdown]
# Add the information from the paper, and convert the temperatures to numbers.

# %%
info_table['rate'] = 8.66e-4  # units (/s) and all tests performed at same rate
info_table['A_0_(mm)'] = np.where(info_table['test_type'] == 'UT', 40.32, 20.16)
info_table['h_0_(mm)'] = 3.175
info_table['temperature'] = pd.to_numeric(info_table['temperature'])

# %% [markdown]
# ### Format the data files.
# In this example, the files are already in .csv format. We just check that the column headers are the same and that there are no duplicates, then rename the files by test id.

# %% [markdown]
# Check column headers, uniqueness.

# %%
pam.check_column_headers('data/01 raw data')
pam.check_for_duplicate_files('data/01 raw data')
# Out:
# Checking column headers...
# First file headers:
# 	['Strain', 'Stress_MPa']
# Headers in all files are the same as in the first file, except for None.
# Checking for duplicate files...
# No duplicate files found in "data/01 raw data".

# %% [markdown]
# Write the prepared data and rename the files by test id. Also write the prepared info table.

# %%
pam.copy_data_and_rename_by_test_id(data_in='data/01 raw data', data_out='data/01 prepared data',
                                    info_table=info_table)
info_table.to_excel('info/01 prepared info.xlsx', index=False)
# Out:
# Copied 76 files in data/01 raw data to data/01 prepared data.

# %% [markdown]
# ### Make the experimental matrix
# We want to identify useful groupings and make visualisations. The tests can be grouped by lot and temperature, with up to 3 repeated tests.

# %%
gold_cmap = mpl.colors.LinearSegmentedColormap.from_list("", ["white", (85 / 255, 49 / 255, 0)])
mpl.rcParams["axes.facecolor"] = gold_cmap(0.1)

# %%
plt.figure(figsize=(2, 2))
pam.experimental_matrix(info_table, index='temperature', columns='lot', as_heatmap=True, cmap=gold_cmap, xlabel='Lot',
                        ylabel='Temperature (°C)', vmax=6);

# %% [markdown]
# ### Visualise the prepared data.
#
# We could colour by lot or by temperature. Colouring by lot is useful to observe variation, colouring by temperature is useful to observe temperature variation.

# %%
def make_strain_percent(di):
    di.data['Strain'] = di.data['Strain'] * 100
    return di


prepared_ds = DataSet('info/01 prepared info.xlsx', 'data/01 prepared data').sort_by(['temperature', 'lot']).apply(
    make_strain_percent)

# %%
lot_styler = pam.Styler(color_by='lot', color_by_label='Lot', cmap='inferno').style_to(prepared_ds)


def ds_subplots(ds: DataSet, **kwargs):
    temperatures = sorted(prepared_ds.info_table['temperature'].unique())
    return pam.dataset_subplots(
        ds=ds, x='Strain', y='Stress_MPa', xlabel='Strain (%)', ylabel='Stress (MPa)',
        styler=lot_styler, plot_legend=False, figsize=(12, 2), shape=(1, 6), ylim=(-25., 350.),
        rows_by='test_type', cols_by='temperature', row_vals=[['UT']],
        col_vals=[[T] for T in temperatures], col_titles=[f'{T}°C' for T in temperatures],
        **kwargs)


ds_subplots(prepared_ds);

# %% [markdown]
# ### Find UTS and Failure

# %%
def find_uts_and_failure(di: DataItem):
    di.info['UTS_1'] = di.data['Stress_MPa'].max()
    di.info['UTS_0'] = di.data['Strain'][di.data['Stress_MPa'].idxmax()]
    di.info['FP_0'] = di.data['Strain'].max()
    return di


prepared_ds = prepared_ds.apply(find_uts_and_failure)

# %% [markdown]
# ### Trimming

# %%
def trim_to_small_strain(di: DataItem):
    di.data = di.data[di.data['Strain'] < 1]
    return di


trimmed_ds = prepared_ds.apply(trim_to_small_strain)

# %% [markdown]
# ### Foot Correction

# %%
corrected_ds = pam.find_upl_and_lpl(trimmed_ds, preload=36, preload_key='Stress_MPa')
corrected_ds = pam.correct_foot(corrected_ds)

# %% [markdown]
# ### Foot correction screening

# %% [markdown]
# Make screening pdf.

# %%
temp_styler = pam.Styler(color_by='temperature', color_by_label='(°C)').style_to(prepared_ds)


def ds_plot(ds: DataSet, **kwargs):
    return pam.dataset_plot(ds, x='Strain', y='Stress_MPa', xlabel='Strain (%)', ylabel='Stress (MPa)',
                            styler=temp_styler, **kwargs)


def foot_correction_screening_plot(di):
    test_id = di.test_id
    temp = di.info['temperature']
    color = temp_styler.color_dict[temp]
    UPL = (di.info['UPL_0'], di.info['UPL_1'])
    LPL = (di.info['LPL_0'], di.info['LPL_1'])
    _ax = ds_plot(corrected_ds.subset({'test_id': [test_id]}))
    _ax = ds_plot(trimmed_ds.subset({'test_id': [test_id]}), alpha=0.5, ax=_ax)
    _ax.axline(UPL, slope=di.info['E'], c=color, ls='--', alpha=0.5, zorder=500 + temp)
    _ax.plot(*UPL, c='k', mfc=color, marker=4, alpha=0.8, markersize=6, zorder=1000 + temp)
    _ax.plot(*LPL, c='k', mfc=color, marker=5, alpha=0.8, markersize=6, zorder=1000 + temp)


foot_correction_screening_plot(corrected_ds[3])
pam.make_screening_pdf(corrected_ds, foot_correction_screening_plot,
                       'info/foot correction screening.pdf');
# Out:
#   0%|          | 0/76 [00:00<?, ?DataItems/s]
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#   1%|▏         | 1/76 [00:00<00:26,  2.79DataItems/s]
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#   3%|▎         | 2/76 [00:00<00:22,  3.28DataItems/s]
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#   4%|▍         | 3/76 [00:00<00:20,  3.57DataItems/s]
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#   5%|▌         | 4/76 [00:01<00:19,  3.69DataItems/s]
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#   7%|▋         | 5/76 [00:01<00:18,  3.85DataItems/s]
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#   8%|▊         | 6/76 [00:01<00:18,  3.84DataItems/s]
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#   9%|▉         | 7/76 [00:01<00:17,  3.84DataItems/s]
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#  11%|█         | 8/76 [00:02<00:17,  3.88DataItems/s]
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#  12%|█▏        | 9/76 [00:02<00:17,  3.91DataItems/s]
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#  13%|█▎        | 10/76 [00:02<00:18,  3.52DataItems/s]
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#  14%|█▍        | 11/76 [00:02<00:17,  3.69DataItems/s]
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#  16%|█▌        | 12/76 [00:03<00:16,  3.80DataItems/s]
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#  17%|█▋        | 13/76 [00:03<00:16,  3.81DataItems/s]
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#  18%|█▊        | 14/76 [00:03<00:16,  3.83DataItems/s]
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#  20%|█▉        | 15/76 [00:04<00:15,  3.88DataItems/s]
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#  21%|██        | 16/76 [00:04<00:15,  3.93DataItems/s]
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#  22%|██▏       | 17/76 [00:04<00:14,  3.95DataItems/s]
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#  24%|██▎       | 18/76 [00:04<00:14,  3.96DataItems/s]
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#  25%|██▌       | 19/76 [00:05<00:14,  3.87DataItems/s]
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#  26%|██▋       | 20/76 [00:05<00:16,  3.39DataItems/s]
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#  28%|██▊       | 21/76 [00:05<00:15,  3.53DataItems/s]
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#  29%|██▉       | 22/76 [00:05<00:14,  3.70DataItems/s]
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#  30%|███       | 23/76 [00:06<00:14,  3.78DataItems/s]
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#  32%|███▏      | 24/76 [00:06<00:13,  3.84DataItems/s]
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#  33%|███▎      | 25/76 [00:06<00:13,  3.83DataItems/s]
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#  34%|███▍      | 26/76 [00:06<00:12,  3.95DataItems/s]
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#  36%|███▌      | 27/76 [00:07<00:12,  3.91DataItems/s]
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#  37%|███▋      | 28/76 [00:07<00:12,  3.98DataItems/s]
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#  38%|███▊      | 29/76 [00:07<00:11,  3.98DataItems/s]
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#  39%|███▉      | 30/76 [00:07<00:11,  3.99DataItems/s]
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#  41%|████      | 31/76 [00:08<00:13,  3.41DataItems/s]
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#  42%|████▏     | 32/76 [00:08<00:12,  3.54DataItems/s]
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#  43%|████▎     | 33/76 [00:08<00:11,  3.69DataItems/s]
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#  45%|████▍     | 34/76 [00:09<00:11,  3.73DataItems/s]
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#  46%|████▌     | 35/76 [00:09<00:10,  3.78DataItems/s]
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#  47%|████▋     | 36/76 [00:09<00:10,  3.86DataItems/s]
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#  49%|████▊     | 37/76 [00:09<00:09,  3.94DataItems/s]
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#  50%|█████     | 38/76 [00:10<00:09,  4.03DataItems/s]
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#  51%|█████▏    | 39/76 [00:10<00:09,  3.99DataItems/s]
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#  53%|█████▎    | 40/76 [00:10<00:09,  3.99DataItems/s]
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#  54%|█████▍    | 41/76 [00:10<00:08,  3.97DataItems/s]
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#  55%|█████▌    | 42/76 [00:11<00:08,  4.05DataItems/s]
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#  57%|█████▋    | 43/76 [00:11<00:08,  4.08DataItems/s]
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#  58%|█████▊    | 44/76 [00:11<00:09,  3.39DataItems/s]
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#  59%|█████▉    | 45/76 [00:11<00:08,  3.53DataItems/s]
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#  61%|██████    | 46/76 [00:12<00:08,  3.62DataItems/s]
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#  62%|██████▏   | 47/76 [00:12<00:07,  3.79DataItems/s]
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#  63%|██████▎   | 48/76 [00:12<00:07,  3.87DataItems/s]
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#  64%|██████▍   | 49/76 [00:12<00:06,  3.95DataItems/s]
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#  66%|██████▌   | 50/76 [00:13<00:06,  3.90DataItems/s]
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#  67%|██████▋   | 51/76 [00:13<00:06,  3.99DataItems/s]
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#  68%|██████▊   | 52/76 [00:13<00:06,  3.99DataItems/s]
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#  70%|██████▉   | 53/76 [00:13<00:05,  4.03DataItems/s]
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#  71%|███████   | 54/76 [00:14<00:05,  3.97DataItems/s]
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#  72%|███████▏  | 55/76 [00:14<00:05,  3.95DataItems/s]
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#  74%|███████▎  | 56/76 [00:14<00:05,  3.94DataItems/s]
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#  75%|███████▌  | 57/76 [00:14<00:04,  3.95DataItems/s]
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#  76%|███████▋  | 58/76 [00:15<00:05,  3.17DataItems/s]
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#  78%|███████▊  | 59/76 [00:15<00:05,  3.31DataItems/s]
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#  79%|███████▉  | 60/76 [00:15<00:04,  3.48DataItems/s]
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#  80%|████████  | 61/76 [00:16<00:04,  3.58DataItems/s]
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#  82%|████████▏ | 62/76 [00:16<00:03,  3.74DataItems/s]
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#  83%|████████▎ | 63/76 [00:16<00:03,  3.86DataItems/s]
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#  84%|████████▍ | 64/76 [00:16<00:03,  3.85DataItems/s]
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#  86%|████████▌ | 65/76 [00:17<00:02,  3.86DataItems/s]
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#  87%|████████▋ | 66/76 [00:17<00:02,  3.89DataItems/s]
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#  88%|████████▊ | 67/76 [00:17<00:02,  3.86DataItems/s]
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#  89%|████████▉ | 68/76 [00:17<00:02,  3.89DataItems/s]
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#  91%|█████████ | 69/76 [00:18<00:01,  3.94DataItems/s]
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#  92%|█████████▏| 70/76 [00:18<00:01,  3.97DataItems/s]
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#  93%|█████████▎| 71/76 [00:18<00:01,  3.95DataItems/s]
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#  95%|█████████▍| 72/76 [00:18<00:01,  3.86DataItems/s]
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#  96%|█████████▌| 73/76 [00:19<00:00,  3.11DataItems/s]
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#  97%|█████████▋| 74/76 [00:19<00:00,  3.33DataItems/s]
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#  99%|█████████▊| 75/76 [00:19<00:00,  3.53DataItems/s]
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
#
#   0%|          | 0/1 [00:00<?, ?DataItems/s]
# Screening pdf saved to info/foot correction screening.pdf.

# %% [markdown]
# Reject flagged tests.

# %%
rejected_ds = pam.read_screening_pdf(corrected_ds, 'info/foot correction screening marked.pdf')
rejected_items = rejected_ds.info_table[rejected_ds.info_table['reject'] == 'True']
rejected_items[['test_id', 'temperature', 'lot', 'number', 'reject', 'comment']]
# Out:
#         test_id  temperature lot  number reject  comment
# 38  test_ID_002          200   A       3   True      NaN
# 45  test_ID_015          200   C       2   True      NaN
# 48  test_ID_018          200   D       2   True      NaN
# 61  test_ID_041          300   A       2   True      NaN
# 71  test_ID_049          300   D       2   True      NaN

# %%
screened_ds = pam.remove_rejected_items(rejected_ds)

# %% [markdown]
# ### Proof Stress

# %%
proof_ds = pam.find_proof_stress(ds=screened_ds, proof_strain=0.2)

# %%
proof_ds.write_output('info/02 processed info.xlsx', 'data/02 processed data')
processed_ds = DataSet('info/02 processed info.xlsx', 'data/02 processed data')

# %% [markdown]
# ### Representative curves

# %%
pam.make_representative_data(processed_ds, 'info/03 repres info.xlsx', 'data/03 repres data',
                             repres_col='Stress_MPa', group_by_keys=['lot', 'temperature', 'test_type'],
                             interp_by='Strain', group_info_cols=['E', 'PS_0.2_1', 'UTS_1', 'UTS_0', 'FP_0', 'UPL_1'])
repres_ds = DataSet('info/03 repres info.xlsx', 'data/03 repres data', test_id_key='repres_id')
ds_subplots(repres_ds, fill_between=('min_Stress_MPa', 'max_Stress_MPa'));

# %% [markdown]
# ### Mechanical properties

# %%
table = pam.make_representative_info(processed_ds, group_by_keys=['temperature', 'test_type'],
                                     group_info_cols=['E', 'PS_0.2_1', 'UTS_1', 'UTS_0', 'FP_0', 'UPL_1'])
table[['temperature', 'nr averaged', 'E', 'PS_0.2_1', 'UTS_1', 'UTS_0', 'FP_0', 'std_PS_0.2_1', 'std_UTS_1',
       'std_UTS_0', 'std_FP_0']].style.hide(axis='index').format('{:.3g}').to_latex('info/04 mechanical properties.tex')

# %% [markdown]
# ### Fitted curves

# %%
ramberg_ms = ModelSet(ramberg, param_names=['C', 'n'], var_names=['E', 'UPL_1'],
                      bounds=[(0., 1000.), (0.01, 0.8)], scipy_func='minimize')

ramberg_ms.fit_to(repres_ds, 'Strain', 'Stress_MPa', sample_size=40)

# %%
ramberg_ds = ramberg_ms.predict()
ds_subplots(ramberg_ds);

# %% [markdown]
# ### Fitting results

# %%
ramberg_ds.info_table
# Out:
#        model_id       var_E   var_UPL_1           C         n      error  \
# 0   model_id_01  611.017082  157.503145  106.662284  0.089410  22.558510
# 1   model_id_02  591.529680  169.863946   64.946765  0.082914   9.314522
# 2   model_id_03  547.633583  102.789679   73.912053  0.094942  30.176575
# 3   model_id_04  360.142237   54.358486   19.575776  0.117059   4.546511
# 4   model_id_05  616.998577  168.508248   81.212860  0.086887  27.615398
# 5   model_id_06  589.815424  157.980391   86.555217  0.102523   4.814263
# 6   model_id_07  546.168752  126.735056   92.436279  0.056485   6.148400
# 7   model_id_08  543.619050  143.062780   46.678311  0.040111   7.464027
# 8   model_id_09  394.301365   92.182226   45.914655  0.136214   6.576198
# 9   model_id_10  514.966624   50.797391   34.873667  0.125932  61.456758
# 10  model_id_11  579.625634  156.691009  132.471054  0.112942  27.823397
# 11  model_id_12  603.268621  142.349373  116.463473  0.075821  16.981852
# 12  model_id_13  518.277089   90.802659  154.677369  0.088748  54.414214
# 13  model_id_14  482.913625  133.092833   75.582747  0.093025  35.837535
# 14  model_id_15  365.081214  103.847011   37.744555  0.080229  22.002157
# 15  model_id_16  440.661070   53.004256   42.276398  0.079405   9.687914
# 16  model_id_17  550.653809  182.812551   84.074790  0.126827  27.393687
# 17  model_id_18  647.591607  116.356679  147.519021  0.114443  52.216966
# 18  model_id_19  456.227109  148.615246   90.232305  0.084769  32.358547
# 19  model_id_20  532.898882   86.144365  125.193506  0.081029  16.693329
# 20  model_id_21  457.694454   63.148979   82.441299  0.096723  30.083489
# 21  model_id_22  468.127006   48.595145   40.043201  0.123392  14.275006
# 22  model_id_23  633.017111  142.441099  117.132043  0.108778  26.141067
# 23  model_id_24  634.910468   95.295245  151.307256  0.065577  29.028295
# 24  model_id_25  501.867998   92.641177  125.821707  0.086811  29.949385
# 25  model_id_26  476.626041  127.037298   63.072918  0.082521   6.236657
# 26  model_id_27  383.833563   90.146024   50.141459  0.073558  15.253693
# 27  model_id_28  507.129164   51.748874   31.660773  0.131777  27.883478
#
#          repres_id lot  temperature test_type  ...  upstd_FP_0  downstd_FP_0  \
# 0   repres_id_0001   A           20        UT  ...   11.897337      9.867595
# 1   repres_id_0002   A          100        UT  ...   18.202901     16.834057
# 2   repres_id_0004   A          200        UT  ...   20.855684     19.811095
# 3   repres_id_0006   A          300        UT  ...   27.391182     12.439033
# 4   repres_id_0007   B           20        UT  ...   11.738586      9.057040
# 5   repres_id_0008   B          100        UT  ...   14.486030     13.231551
# 6   repres_id_0009   B          150        UT  ...   22.912655     18.646551
# 7   repres_id_0010   B          200        UT  ...   16.212487     15.377102
# 8   repres_id_0011   B          250        UT  ...   16.775987     15.983926
# 9   repres_id_0012   B          300        UT  ...   19.254916     15.818184
# 10  repres_id_0013   C           20        UT  ...   14.006902      7.750050
# 11  repres_id_0014   C          100        UT  ...   17.632841     14.976431
# 12  repres_id_0015   C          150        UT  ...   16.564221     15.688019
# 13  repres_id_0016   C          200        UT  ...   12.664817     11.122159
# 14  repres_id_0017   C          250        UT  ...   12.315770     10.107935
# 15  repres_id_0018   C          300        UT  ...   14.257270     11.493049
# 16  repres_id_0019   D           20        UT  ...   12.038501      9.307457
# 17  repres_id_0020   D          100        UT  ...   15.051561      9.701372
# 18  repres_id_0021   D          150        UT  ...   20.651124     15.533178
# 19  repres_id_0022   D          200        UT  ...   19.104979      9.428508
# 20  repres_id_0023   D          250        UT  ...   16.097675     10.902285
# 21  repres_id_0024   D          300        UT  ...   19.078149     16.679429
# 22  repres_id_0025   E           20        UT  ...   12.838438     10.961846
# 23  repres_id_0026   E          100        UT  ...   19.467476     14.755861
# 24  repres_id_0027   E          150        UT  ...   29.200112     21.364210
# 25  repres_id_0028   E          200        UT  ...   20.993638     19.186393
# 26  repres_id_0029   E          250        UT  ...   17.333638     13.649316
# 27  repres_id_0030   E          300        UT  ...   22.132474     19.091879
#
#      max_FP_0   min_FP_0       UPL_1  std_UPL_1  upstd_UPL_1  downstd_UPL_1  \
# 0   11.917776   9.889350  157.503145  41.468662   198.971806     116.034483
# 1   18.252270  16.897425  169.863946  19.647513   189.511459     150.216433
# 2   20.702707  19.964071  102.789679  44.615416   147.405094      58.174263
# 3   25.201491  14.628724   54.358486   3.637884    57.996370      50.720602
# 4   11.335128   8.862032  168.508248  60.027650   228.535898     108.480598
# 5   14.514066  13.263964  157.980391  12.769879   170.750270     145.210511
# 6   22.287899  19.271308  126.735056   0.575770   127.310827     126.159286
# 7   16.275938  15.525191  143.062780  14.131964   157.194744     128.930816
# 8   16.659992  16.099921   92.182226   3.682034    95.864260      88.500192
# 9   19.392554  16.000915   50.797391   6.850346    57.647737      43.947046
# 10  12.734776   7.266548  156.691009  25.240262   181.931271     131.450746
# 11  17.186275  14.777003  142.349373  60.113596   202.462969      82.235777
# 12  16.435904  15.816336   90.802659  66.626865   157.429524      24.175794
# 13  12.438900  11.348076  133.092833  26.694562   159.787395     106.398271
# 14  11.992440  10.431265  103.847011  19.993644   123.840655      83.853366
# 15  14.340289  11.594620   53.004256  10.777613    63.781869      42.226643
# 16  12.139027   9.437285  182.812551  16.834737   199.647289     165.977814
# 17  15.371202  10.223508  116.356679  69.900472   186.257151      46.456207
# 18  19.901618  16.282684  148.615246  59.667739   208.282985      88.947507
# 19  17.687892  10.845594   86.144365  48.334278   134.478643      37.810087
# 20  15.336828  11.663132   63.148979  23.304693    86.453672      39.844286
# 21  18.726864  17.030714   48.595145   7.789876    56.385021      40.805269
# 22  12.733407  10.883800  142.441099  74.813152   217.254251      67.627947
# 23  19.366271  14.666261   95.295245  84.932127   180.227372      10.363118
# 24  28.052571  22.511751   92.641177   8.021882   100.663059      84.619295
# 25  20.926311  19.131506  127.037298   9.871995   136.909293     117.165303
# 26  16.794081  14.188872   90.146024  28.193589   118.339613      61.952436
# 27  22.242067  19.232522   51.748874   9.350681    61.099555      42.398194
#
#      max_UPL_1   min_UPL_1
# 0   198.512982  115.590404
# 1   184.962353  147.650045
# 2   134.337542   71.241816
# 3    56.930859   51.786114
# 4   212.461145  100.116006
# 5   166.148394  143.264709
# 6   127.142187  126.327925
# 7   152.399410  126.804257
# 8    94.785818   89.578635
# 9    57.035151   43.466030
# 10  183.564032  133.484578
# 11  211.281862  100.820664
# 12  137.914967   43.690351
# 13  151.968739  114.216927
# 14  117.984652   89.709369
# 15   61.768177   40.970355
# 16  197.823709  164.610840
# 17  185.923508   46.127274
# 18  190.806709  106.423783
# 19  120.321861   51.966869
# 20   79.627885   46.670073
# 21   54.103420   43.086871
# 22  191.932804   56.376929
# 23  193.341583   44.360834
# 24   98.313505   86.968850
# 25  137.529404  117.932092
# 26  110.081902   70.210147
# 27   59.721656   41.456828
#
# [28 rows x 47 columns]

# %%
table = pam.make_representative_info(ramberg_ds, group_by_keys=['temperature', 'test_type'],
                                     group_info_cols=['E', 'UPL_1', 'C', 'n', 'error'])
table[['temperature', 'nr averaged', 'E', 'UPL_1', 'C', 'n', 'error']].style.hide(axis='index').format(
    '{:.3g}').to_latex('info/05 fitting results.tex')
